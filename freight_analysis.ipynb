# %% [markdown]
# # Supply Chain Freight Analysis

# %%
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('../Dataset/freight_data.csv')
df.head()

# %%
# Vendor freight cost
vendor_cost = df.groupby('Vendor_Name')['Freight_Charges'].sum()
vendor_cost.plot(kind='bar')
plt.show()
